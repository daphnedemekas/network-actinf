# %%
import numpy as np

# %%
import seaborn as sns

# %%
actions_over_time_all = np.load('sweep/3,3.5,4,4.5,5,5.5,6/actions_over_time_all.npy')

# %%
B1_over_time_all = np.load('sweep/3,3.5,4,4.5,5,5.5,6/B1_over_time_all.npy')

# %%
B2_over_time_all = np.load('sweep/3,3.5,4,4.5,5,5.5,6/B2_over_time_all.npy')

# %%
q_pi_over_time_all = np.load('sweep/3,3.5,4,4.5,5,5.5,6/q_pi_over_time_all.npy')

# %%
q_pi_over_time_all.shape
# Out:
# (200, 2, 2, 6, 2)

# %%
B1_over_time_all.shape
# Out:
# (200, 4, 4, 2, 2, 6, 2)

# %%
import matplotlib.pyplot as plt

# %%
from matplotlib.colors import LinearSegmentedColormap

cmap0 = LinearSegmentedColormap.from_list("", ["white", "black"])

# %%
def set_labels(axis):
    axis.set_xticklabels(['CC','CD','DC','DD'])
    axis.set_yticklabels(['CC','CD'])

fig, ax = plt.subplots(2,3, figsize = (12,4))

img1 = sns.heatmap(B1_over_time_all[-1,:2,:,0,0,0,0],ax =ax[0,0], cmap = cmap0, vmin = 0, vmax =1)
img2 = sns.heatmap(B1_over_time_all[-1,:2,:,0,0,1,0],ax =ax[0,1], cmap = cmap0, vmin = 0, vmax =1)
img3 = sns.heatmap(B1_over_time_all[-1,:2,:,0,0,2,0],ax =ax[0,2], cmap = cmap0, vmin = 0, vmax =1)
img4 = sns.heatmap(B1_over_time_all[-1,:2,:,0,0,3,0],ax =ax[1,0], cmap = cmap0, vmin = 0, vmax =1)
img5 = sns.heatmap(B1_over_time_all[-1,:2,:,0,0,4,0],ax =ax[1,1], cmap = cmap0, vmin = 0, vmax =1)
img6 = sns.heatmap(B1_over_time_all[-1,:2,:,0,0,5,0],ax =ax[1,2], cmap = cmap0, vmin = 0, vmax =1)

ax[0,0].set_title(" p = 3")
ax[0,1].set_title(" p = 3.5")

ax[0,2].set_title(" p = 4")
ax[1,0].set_title(" p = 4.5")
ax[1,1].set_title(" p = 5")
ax[1,2].set_title(" p = 5.5")

set_labels(ax[0,0])
set_labels(ax[0,1])
set_labels(ax[0,2])
set_labels(ax[1,0])
set_labels(ax[1,1])
set_labels(ax[1,2])
fig.suptitle("Learned Transitions given action cooperate")
fig.tight_layout()

# %%
def set_labels(axis):
    axis.set_xticklabels(['CC','CD','DC','DD'])
    axis.set_yticklabels(['DC','DD'])

fig, ax = plt.subplots(2,3, figsize = (12,4))

img1 = sns.heatmap(B1_over_time_all[-1,2:,:,1,0,0,0],ax =ax[0,0], cmap = cmap0, vmin = 0, vmax =1)
img2 = sns.heatmap(B1_over_time_all[-1,2:,:,1,0,1,0],ax =ax[0,1], cmap = cmap0, vmin = 0, vmax =1)
img3 = sns.heatmap(B1_over_time_all[-1,2:,:,1,0,2,0],ax =ax[0,2], cmap = cmap0, vmin = 0, vmax =1)
img4 = sns.heatmap(B1_over_time_all[-1,2:,:,1,0,3,0],ax =ax[1,0], cmap = cmap0, vmin = 0, vmax =1)
img5 = sns.heatmap(B1_over_time_all[-1,2:,:,1,0,4,0],ax =ax[1,1], cmap = cmap0, vmin = 0, vmax =1)
img6 = sns.heatmap(B1_over_time_all[-1,2:,:,1,0,5,0],ax =ax[1,2], cmap = cmap0, vmin = 0, vmax =1)

ax[0,0].set_title(" p = 3")
ax[0,1].set_title(" p = 3.5")

ax[0,2].set_title(" p = 4")
ax[1,0].set_title(" p = 4.5")
ax[1,1].set_title(" p = 5")
ax[1,2].set_title(" p = 5.5")

set_labels(ax[0,0])
set_labels(ax[0,1])
set_labels(ax[0,2])
set_labels(ax[1,0])
set_labels(ax[1,1])
set_labels(ax[1,2])
fig.tight_layout()

fig.suptitle("Learned Transitions given action defect")
fig.tight_layout()

# %%
B2_over_time_all[-1,:,:,0,0,0,0]
# Out:
# array([[0.78213004, 0.78977033],
#        [0.21786996, 0.21022967]])

# %%
B2_over_time_all[-1,:,:,0,0,-1,0]
# Out:
# array([[0.91840364, 0.90547877],
#        [0.08159636, 0.09452123]])

# %%
def set_labels(axis):
    axis.set_xticklabels(['Prosocial','Antisocial'])
    axis.set_yticklabels(['PS','AS'])

fig, ax = plt.subplots(2,3, figsize = (12,4))

img1 = sns.heatmap(B2_over_time_all[-1,:,:,0,0,0,0],ax =ax[0,0], cmap = cmap0, vmin = 0, vmax =1)
img2 = sns.heatmap(B2_over_time_all[-1,:,:,0,0,1,0],ax =ax[0,1], cmap = cmap0, vmin = 0, vmax =1)
img3 = sns.heatmap(B2_over_time_all[-1,:,:,0,0,2,0],ax =ax[0,2], cmap = cmap0, vmin = 0, vmax =1)
img4 = sns.heatmap(B2_over_time_all[-1,:,:,0,0,3,0],ax =ax[1,0], cmap = cmap0, vmin = 0, vmax =1)
img5 = sns.heatmap(B2_over_time_all[-1,:,:,0,0,4,0],ax =ax[1,1], cmap = cmap0, vmin = 0, vmax =1)
img6 = sns.heatmap(B2_over_time_all[-1,:,:,0,0,5,0],ax =ax[1,2], cmap = cmap0, vmin = 0, vmax =1)
set_labels(ax[0,0])
set_labels(ax[0,1])
set_labels(ax[0,2])
set_labels(ax[1,0])
set_labels(ax[1,1])
set_labels(ax[1,2])
fig.tight_layout()

fig.suptitle("Learned Transitions given action cooperate")
fig.tight_layout()

# %%
def set_labels(axis):
    axis.set_xticklabels(['Prosocial','Antisocial'])
    axis.set_yticklabels(['PS','AS'])

fig, ax = plt.subplots(2,3, figsize = (12,4))

img1 = sns.heatmap(B2_over_time_all[-1,:,:,1,0,0,0],ax =ax[0,0], cmap = cmap0, vmin = 0, vmax =1)
img2 = sns.heatmap(B2_over_time_all[-1,:,:,1,0,1,0],ax =ax[0,1], cmap = cmap0, vmin = 0, vmax =1)
img3 = sns.heatmap(B2_over_time_all[-1,:,:,1,0,2,0],ax =ax[0,2], cmap = cmap0, vmin = 0, vmax =1)
img4 = sns.heatmap(B2_over_time_all[-1,:,:,1,0,3,0],ax =ax[1,0], cmap = cmap0, vmin = 0, vmax =1)
img5 = sns.heatmap(B2_over_time_all[-1,:,:,1,0,4,0],ax =ax[1,1], cmap = cmap0, vmin = 0, vmax =1)
img6 = sns.heatmap(B2_over_time_all[-1,:,:,1,0,5,0],ax =ax[1,2], cmap = cmap0, vmin = 0, vmax =1)
set_labels(ax[0,0])
set_labels(ax[0,1])
set_labels(ax[0,2])
set_labels(ax[1,0])
set_labels(ax[1,1])
set_labels(ax[1,2])
fig.tight_layout()

fig.suptitle("Learned Transitions given action defect")
fig.tight_layout()

# %%
q_pi_over_time_all[0,0,0,:,0] = 0.5

# %%
for i in range(4):
    plt.plot(q_pi_over_time_all[:,0,0,i,0])
    #plt.errorbar(range(200), q_pi_over_time_all[:,0,0,i,0], yerr=q_pi_over_time_all[:,0,0,i,1],alpha=0.5, ecolor = 'yellow')

    plt.show()

# %%
for i in range(4):
    fig, ax = plt.subplots()
    ax.grid(color='w', which = 'minor', linestyle='-', linewidth=2)
    ax.set_xlabel("Time")
    im = ax.imshow(actions_over_time_all[:,:,i].T,cmap ='gray', aspect = 10)
    ax.set_yticks([0, 1], labels=["Agent 1", "Agent 2"])
    plt.title(
        f"Actions over time for A precisions"
    )
    plt.show()

# %%
actions_over_time_all = np.load('sweep/lr_pB/actions_over_time_all.npy')
B1_over_time_all = np.load('sweep/lr_pB/B1_over_time_all.npy')
B2_over_time_all = np.load('sweep/lr_pB/B2_over_time_all.npy')
q_pi_over_time_all = np.load('sweep/lr_pB/q_pi_over_time_all.npy')

# %%
def set_labels(axis):
    axis.set_xticklabels(['CC','CD','DC','DD'])
    axis.set_yticklabels(['CC','CD'])

fig, ax = plt.subplots(2,3, figsize = (12,4))

img1 = sns.heatmap(B1_over_time_all[-1,:2,:,0,0,0,0],ax =ax[0,0], cmap = cmap0, vmin = 0, vmax =1)
img2 = sns.heatmap(B1_over_time_all[-1,:2,:,0,0,1,0],ax =ax[0,1], cmap = cmap0, vmin = 0, vmax =1)
img3 = sns.heatmap(B1_over_time_all[-1,:2,:,0,0,2,0],ax =ax[0,2], cmap = cmap0, vmin = 0, vmax =1)
img4 = sns.heatmap(B1_over_time_all[-1,:2,:,0,0,3,0],ax =ax[1,0], cmap = cmap0, vmin = 0, vmax =1)
img5 = sns.heatmap(B1_over_time_all[-1,:2,:,0,0,4,0],ax =ax[1,1], cmap = cmap0, vmin = 0, vmax =1)
img6 = sns.heatmap(B1_over_time_all[-1,:2,:,0,0,5,0],ax =ax[1,2], cmap = cmap0, vmin = 0, vmax =1)

ax[0,0].set_title(" lr = 0.3")
ax[0,1].set_title(" lr = 0.5")

ax[0,2].set_title(" lr = 0.7")
ax[1,0].set_title(" lr = 0.9")
ax[1,1].set_title(" lr = 1.1")
ax[1,2].set_title(" lr = 1.3")

set_labels(ax[0,0])
set_labels(ax[0,1])
set_labels(ax[0,2])
set_labels(ax[1,0])
set_labels(ax[1,1])
set_labels(ax[1,2])
fig.suptitle("Learned Transitions given action cooperate")
fig.tight_layout()

# %%
def set_labels(axis):
    axis.set_xticklabels(['CC','CD','DC','DD'])
    axis.set_yticklabels(['CC','CD'])

fig, ax = plt.subplots(2,3, figsize = (12,4))

img1 = sns.heatmap(B1_over_time_all[-1,2:,:,1,0,0,0],ax =ax[0,0], cmap = cmap0, vmin = 0, vmax =1)
img2 = sns.heatmap(B1_over_time_all[-1,2:,:,1,0,1,0],ax =ax[0,1], cmap = cmap0, vmin = 0, vmax =1)
img3 = sns.heatmap(B1_over_time_all[-1,2:,:,1,0,2,0],ax =ax[0,2], cmap = cmap0, vmin = 0, vmax =1)
img4 = sns.heatmap(B1_over_time_all[-1,2:,:,1,0,3,0],ax =ax[1,0], cmap = cmap0, vmin = 0, vmax =1)
img5 = sns.heatmap(B1_over_time_all[-1,2:,:,1,0,4,0],ax =ax[1,1], cmap = cmap0, vmin = 0, vmax =1)
img6 = sns.heatmap(B1_over_time_all[-1,2:,:,1,0,5,0],ax =ax[1,2], cmap = cmap0, vmin = 0, vmax =1)

ax[0,0].set_title(" lr = 0.3")
ax[0,1].set_title(" lr = 0.5")

ax[0,2].set_title(" lr = 0.7")
ax[1,0].set_title(" lr = 0.9")
ax[1,1].set_title(" lr = 1.1")
ax[1,2].set_title(" lr = 1.3")

set_labels(ax[0,0])
set_labels(ax[0,1])
set_labels(ax[0,2])
set_labels(ax[1,0])
set_labels(ax[1,1])
set_labels(ax[1,2])
fig.suptitle("Learned Transitions given action defect")
fig.tight_layout()

# %%
def set_labels(axis):
    axis.set_xticklabels(['Prosocial','Antisocial'])
    axis.set_yticklabels(['PS','AS'])

fig, ax = plt.subplots(2,3, figsize = (12,4))

img1 = sns.heatmap(B2_over_time_all[-1,:,:,0,0,0,0],ax =ax[0,0], cmap = cmap0, vmin = 0, vmax =1)
img2 = sns.heatmap(B2_over_time_all[-1,:,:,0,0,1,0],ax =ax[0,1], cmap = cmap0, vmin = 0, vmax =1)
img3 = sns.heatmap(B2_over_time_all[-1,:,:,0,0,2,0],ax =ax[0,2], cmap = cmap0, vmin = 0, vmax =1)
img4 = sns.heatmap(B2_over_time_all[-1,:,:,0,0,3,0],ax =ax[1,0], cmap = cmap0, vmin = 0, vmax =1)
img5 = sns.heatmap(B2_over_time_all[-1,:,:,0,0,4,0],ax =ax[1,1], cmap = cmap0, vmin = 0, vmax =1)
img6 = sns.heatmap(B2_over_time_all[-1,:,:,0,0,5,0],ax =ax[1,2], cmap = cmap0, vmin = 0, vmax =1)
set_labels(ax[0,0])
set_labels(ax[0,1])
set_labels(ax[0,2])
set_labels(ax[1,0])
set_labels(ax[1,1])
set_labels(ax[1,2])
fig.tight_layout()

fig.suptitle("Learned Transitions given action cooperate")
fig.tight_layout()

# %%
def set_labels(axis):
    axis.set_xticklabels(['Prosocial','Antisocial'])
    axis.set_yticklabels(['PS','AS'])

fig, ax = plt.subplots(2,3, figsize = (12,4))

img1 = sns.heatmap(B2_over_time_all[-1,:,:,1,0,0,0],ax =ax[0,0], cmap = cmap0, vmin = 0, vmax =1)
img2 = sns.heatmap(B2_over_time_all[-1,:,:,1,0,1,0],ax =ax[0,1], cmap = cmap0, vmin = 0, vmax =1)
img3 = sns.heatmap(B2_over_time_all[-1,:,:,1,0,2,0],ax =ax[0,2], cmap = cmap0, vmin = 0, vmax =1)
img4 = sns.heatmap(B2_over_time_all[-1,:,:,1,0,3,0],ax =ax[1,0], cmap = cmap0, vmin = 0, vmax =1)
img5 = sns.heatmap(B2_over_time_all[-1,:,:,1,0,4,0],ax =ax[1,1], cmap = cmap0, vmin = 0, vmax =1)
img6 = sns.heatmap(B2_over_time_all[-1,:,:,1,0,5,0],ax =ax[1,2], cmap = cmap0, vmin = 0, vmax =1)
set_labels(ax[0,0])
set_labels(ax[0,1])
set_labels(ax[0,2])
set_labels(ax[1,0])
set_labels(ax[1,1])
set_labels(ax[1,2])
fig.tight_layout()

fig.suptitle("Learned Transitions given action defect")
fig.tight_layout()

# %%
for i in range(3):
    plt.plot(q_pi_over_time_all[:,0,0,i,0])
    #plt.errorbar(range(200), q_pi_over_time_all[:,0,0,i,0], yerr=q_pi_over_time_all[:,0,0,i,1],alpha=0.5, ecolor = 'yellow')

    plt.show()

# %%
for i in range(3):
    fig, ax = plt.subplots()
    ax.grid(color='w', which = 'minor', linestyle='-', linewidth=2)
    ax.set_xlabel("Time")
    im = ax.imshow(actions_over_time_all[:,:,i].T,cmap ='gray', aspect = 10)
    ax.set_yticks([0, 1], labels=["Agent 1", "Agent 2"])
    plt.title(
        f"Actions over time for A precisions"
    )
    plt.show()
