# %%
import numpy as np

# %%
import seaborn as sns

# %%
actions_over_time_all_trials = np.load('pa_sweep_all_trials_4_to_6.5/actions_over_time_all.npy')

# %%
B1_over_time_all_trials = np.load('pa_sweep_all_trials_4_to_6.5/B1_over_time_all.npy')

# %%
B2_over_time_all_trials = np.load('pa_sweep_all_trials_4_to_6.5/B2_over_time_all.npy')

# %%
q_pi_over_time_all_trials = np.load('pa_sweep_all_trials_4_to_6.5/q_pi_over_time_all.npy')

# %%
q_pi_over_time_all_trials.shape
# Out:
# (200, 2, 2, 6, 100)

# %%
B1_over_time_all_trials.shape
# Out:
# (200, 4, 4, 2, 2, 6, 100)

# %%
actions_over_time_all_trials.shape
# Out:
# (200, 2, 6, 100)

# %%
actions_over_time_all = np.mean(actions_over_time_all_trials,axis=-1)
B1_over_time_all = np.mean(B1_over_time_all_trials,axis=-1)
B2_over_time_all = np.mean(B2_over_time_all_trials,axis=-1)
q_pi_over_time_all = np.mean(q_pi_over_time_all_trials,axis=-1)

# %%
import matplotlib.pyplot as plt

# %%
from matplotlib.colors import LinearSegmentedColormap

cmap0 = LinearSegmentedColormap.from_list("", ["white", "black"])

# %%
B1_over_time_all.shape
# Out:
# (200, 4, 4, 2, 2, 6)

# %%
def set_labels(axis):
    axis.set_xticklabels(['CC','CD','DC','DD'])
    axis.set_yticklabels(['CC','CD'])

fig, ax = plt.subplots(2,3, figsize = (12,4))

img1 = sns.heatmap(B1_over_time_all[-1,:2,:,0,0,0],ax =ax[0,0], cmap = cmap0, vmin = 0, vmax =1)
img2 = sns.heatmap(B1_over_time_all[-1,:2,:,0,0,1],ax =ax[0,1], cmap = cmap0, vmin = 0, vmax =1)
img3 = sns.heatmap(B1_over_time_all[-1,:2,:,0,0,2],ax =ax[0,2], cmap = cmap0, vmin = 0, vmax =1)
img4 = sns.heatmap(B1_over_time_all[-1,:2,:,0,0,3],ax =ax[1,0], cmap = cmap0, vmin = 0, vmax =1)
img5 = sns.heatmap(B1_over_time_all[-1,:2,:,0,0,4],ax =ax[1,1], cmap = cmap0, vmin = 0, vmax =1)
img6 = sns.heatmap(B1_over_time_all[-1,:2,:,0,0,5],ax =ax[1,2], cmap = cmap0, vmin = 0, vmax =1)

ax[0,0].set_title(" p = 2.0")
ax[0,1].set_title(" p = 3.0")

ax[0,2].set_title(" p = 4.0")
ax[1,0].set_title(" p = 5.0")
ax[1,1].set_title(" p = 6.0")
ax[1,2].set_title(" p = 7.0")

set_labels(ax[0,0])
set_labels(ax[0,1])
set_labels(ax[0,2])
set_labels(ax[1,0])
set_labels(ax[1,1])
set_labels(ax[1,2])
fig.suptitle("Learned Transitions given action cooperate")
fig.tight_layout()

# %%
def set_labels(axis):
    axis.set_xticklabels(['CC','CD','DC','DD'])
    axis.set_yticklabels(['DC','DD'])

fig, ax = plt.subplots(2,3, figsize = (12,4))

img1 = sns.heatmap(B1_over_time_all[-1,2:,:,1,0,0],ax =ax[0,0], cmap = cmap0, vmin = 0, vmax =1)
img2 = sns.heatmap(B1_over_time_all[-1,2:,:,1,0,1],ax =ax[0,1], cmap = cmap0, vmin = 0, vmax =1)
img3 = sns.heatmap(B1_over_time_all[-1,2:,:,1,0,2],ax =ax[0,2], cmap = cmap0, vmin = 0, vmax =1)
img4 = sns.heatmap(B1_over_time_all[-1,2:,:,1,0,3],ax =ax[1,0], cmap = cmap0, vmin = 0, vmax =1)
img5 = sns.heatmap(B1_over_time_all[-1,2:,:,1,0,4],ax =ax[1,1], cmap = cmap0, vmin = 0, vmax =1)
img6 = sns.heatmap(B1_over_time_all[-1,2:,:,1,0,5],ax =ax[1,2], cmap = cmap0, vmin = 0, vmax =1)

ax[0,0].set_title(" p = 2.0")
ax[0,1].set_title(" p = 3.0")

ax[0,2].set_title(" p = 4.0")
ax[1,0].set_title(" p = 5.0")
ax[1,1].set_title(" p = 6.0")
ax[1,2].set_title(" p = 7.0")

set_labels(ax[0,0])
set_labels(ax[0,1])
set_labels(ax[0,2])
set_labels(ax[1,0])
set_labels(ax[1,1])
set_labels(ax[1,2])
fig.tight_layout()

fig.suptitle("Learned Transitions given action defect")
fig.tight_layout()

# %%
def set_labels(axis):
    axis.set_xticklabels(['Prosocial','Antisocial'])
    axis.set_yticklabels(['PS','AS'])

fig, ax = plt.subplots(2,3, figsize = (12,4))

img1 = sns.heatmap(B2_over_time_all[-1,:,:,0,0,0],ax =ax[0,0], cmap = cmap0, vmin = 0, vmax =1)
img2 = sns.heatmap(B2_over_time_all[-1,:,:,0,0,1],ax =ax[0,1], cmap = cmap0, vmin = 0, vmax =1)
img3 = sns.heatmap(B2_over_time_all[-1,:,:,0,0,2],ax =ax[0,2], cmap = cmap0, vmin = 0, vmax =1)
img4 = sns.heatmap(B2_over_time_all[-1,:,:,0,0,3],ax =ax[1,0], cmap = cmap0, vmin = 0, vmax =1)
img5 = sns.heatmap(B2_over_time_all[-1,:,:,0,0,4],ax =ax[1,1], cmap = cmap0, vmin = 0, vmax =1)
img6 = sns.heatmap(B2_over_time_all[-1,:,:,0,0,5],ax =ax[1,2], cmap = cmap0, vmin = 0, vmax =1)
set_labels(ax[0,0])
set_labels(ax[0,1])
set_labels(ax[0,2])
set_labels(ax[1,0])
set_labels(ax[1,1])
set_labels(ax[1,2])
fig.tight_layout()

fig.suptitle("Learned Transitions given action cooperate")
fig.tight_layout()

# %%
def set_labels(axis):
    axis.set_xticklabels(['Prosocial','Antisocial'])
    axis.set_yticklabels(['PS','AS'])

fig, ax = plt.subplots(2,3, figsize = (12,4))

img1 = sns.heatmap(B2_over_time_all[-1,:,:,1,0,0],ax =ax[0,0], cmap = cmap0, vmin = 0, vmax =1)
img2 = sns.heatmap(B2_over_time_all[-1,:,:,1,0,1],ax =ax[0,1], cmap = cmap0, vmin = 0, vmax =1)
img3 = sns.heatmap(B2_over_time_all[-1,:,:,1,0,2],ax =ax[0,2], cmap = cmap0, vmin = 0, vmax =1)
img4 = sns.heatmap(B2_over_time_all[-1,:,:,1,0,3],ax =ax[1,0], cmap = cmap0, vmin = 0, vmax =1)
img5 = sns.heatmap(B2_over_time_all[-1,:,:,1,0,4],ax =ax[1,1], cmap = cmap0, vmin = 0, vmax =1)
img6 = sns.heatmap(B2_over_time_all[-1,:,:,1,0,5],ax =ax[1,2], cmap = cmap0, vmin = 0, vmax =1)
set_labels(ax[0,0])
set_labels(ax[0,1])
set_labels(ax[0,2])
set_labels(ax[1,0])
set_labels(ax[1,1])
set_labels(ax[1,2])
fig.tight_layout()

fig.suptitle("Learned Transitions given action defect")
fig.tight_layout()

# %%
for i in range(6):
    plt.plot(q_pi_over_time_all[:,0,0,i])
    plt.ylim([0,1])
    #plt.errorbar(range(200), q_pi_over_time_all[:,0,0,i,0], yerr=q_pi_over_time_all[:,0,0,i,1],alpha=0.5, ecolor = 'yellow')

    plt.show()

# %%
for i in range(6):
    fig, ax = plt.subplots()
    ax.grid(color='w', which = 'minor', linestyle='-', linewidth=2)
    ax.set_xlabel("Time")
    im = ax.imshow(actions_over_time_all[:,:,i].T,cmap ='gray', aspect = 10, vmin=0, vmax =1)
    ax.set_yticks([0, 1], labels=["Agent 1", "Agent 2"])
    plt.title(
        f"Actions over time for A precisions"
    )
    plt.show()

# %%
actions_over_time_all_trials = np.load('lr_sweep/actions_over_time_all.npy')
B1_over_time_all_trials = np.load('lr_sweep/B1_over_time_all.npy')
B2_over_time_all_trials = np.load('lr_sweep/B2_over_time_all.npy')
q_pi_over_time_all_trials = np.load('lr_sweep/q_pi_over_time_all.npy')

# %%
actions_over_time_all = np.mean(actions_over_time_all_trials,axis=-1)
B1_over_time_all = np.mean(B1_over_time_all_trials,axis=-1)
B2_over_time_all = np.mean(B2_over_time_all_trials,axis=-1)
q_pi_over_time_all = np.mean(q_pi_over_time_all_trials,axis=-1)

# %%
def set_labels(axis):
    axis.set_xticklabels(['CC','CD','DC','DD'])
    axis.set_yticklabels(['CC','CD'])

fig, ax = plt.subplots(2,3, figsize = (12,4))

img1 = sns.heatmap(B1_over_time_all[-1,:2,:,0,0,0],ax =ax[0,0], cmap = cmap0, vmin = 0, vmax =1)
img2 = sns.heatmap(B1_over_time_all[-1,:2,:,0,0,1],ax =ax[0,1], cmap = cmap0, vmin = 0, vmax =1)
img3 = sns.heatmap(B1_over_time_all[-1,:2,:,0,0,2],ax =ax[0,2], cmap = cmap0, vmin = 0, vmax =1)
img4 = sns.heatmap(B1_over_time_all[-1,:2,:,0,0,3],ax =ax[1,0], cmap = cmap0, vmin = 0, vmax =1)
img5 = sns.heatmap(B1_over_time_all[-1,:2,:,0,0,4],ax =ax[1,1], cmap = cmap0, vmin = 0, vmax =1)
img6 = sns.heatmap(B1_over_time_all[-1,:2,:,0,0,5],ax =ax[1,2], cmap = cmap0, vmin = 0, vmax =1)

ax[0,0].set_title(" p = 2.0")
ax[0,1].set_title(" p = 3.0")

ax[0,2].set_title(" p = 4.0")
ax[1,0].set_title(" p = 5.0")
ax[1,1].set_title(" p = 6.0")
ax[1,2].set_title(" p = 7.0")

set_labels(ax[0,0])
set_labels(ax[0,1])
set_labels(ax[0,2])
set_labels(ax[1,0])
set_labels(ax[1,1])
set_labels(ax[1,2])
fig.suptitle("Learned Transitions given action cooperate")
fig.tight_layout()

# %%
def set_labels(axis):
    axis.set_xticklabels(['CC','CD','DC','DD'])
    axis.set_yticklabels(['DC','DD'])

fig, ax = plt.subplots(2,3, figsize = (12,4))

img1 = sns.heatmap(B1_over_time_all[-1,2:,:,1,0,0],ax =ax[0,0], cmap = cmap0, vmin = 0, vmax =1)
img2 = sns.heatmap(B1_over_time_all[-1,2:,:,1,0,1],ax =ax[0,1], cmap = cmap0, vmin = 0, vmax =1)
img3 = sns.heatmap(B1_over_time_all[-1,2:,:,1,0,2],ax =ax[0,2], cmap = cmap0, vmin = 0, vmax =1)
img4 = sns.heatmap(B1_over_time_all[-1,2:,:,1,0,3],ax =ax[1,0], cmap = cmap0, vmin = 0, vmax =1)
img5 = sns.heatmap(B1_over_time_all[-1,2:,:,1,0,4],ax =ax[1,1], cmap = cmap0, vmin = 0, vmax =1)
img6 = sns.heatmap(B1_over_time_all[-1,2:,:,1,0,5],ax =ax[1,2], cmap = cmap0, vmin = 0, vmax =1)

ax[0,0].set_title(" p = 2.0")
ax[0,1].set_title(" p = 3.0")

ax[0,2].set_title(" p = 4.0")
ax[1,0].set_title(" p = 5.0")
ax[1,1].set_title(" p = 6.0")
ax[1,2].set_title(" p = 7.0")

set_labels(ax[0,0])
set_labels(ax[0,1])
set_labels(ax[0,2])
set_labels(ax[1,0])
set_labels(ax[1,1])
set_labels(ax[1,2])
fig.tight_layout()

fig.suptitle("Learned Transitions given action defect")
fig.tight_layout()

# %%
def set_labels(axis):
    axis.set_xticklabels(['Prosocial','Antisocial'])
    axis.set_yticklabels(['PS','AS'])

fig, ax = plt.subplots(2,3, figsize = (12,4))

img1 = sns.heatmap(B2_over_time_all[-1,:,:,0,0,0],ax =ax[0,0], cmap = cmap0, vmin = 0, vmax =1)
img2 = sns.heatmap(B2_over_time_all[-1,:,:,0,0,1],ax =ax[0,1], cmap = cmap0, vmin = 0, vmax =1)
img3 = sns.heatmap(B2_over_time_all[-1,:,:,0,0,2],ax =ax[0,2], cmap = cmap0, vmin = 0, vmax =1)
img4 = sns.heatmap(B2_over_time_all[-1,:,:,0,0,3],ax =ax[1,0], cmap = cmap0, vmin = 0, vmax =1)
img5 = sns.heatmap(B2_over_time_all[-1,:,:,0,0,4],ax =ax[1,1], cmap = cmap0, vmin = 0, vmax =1)
img6 = sns.heatmap(B2_over_time_all[-1,:,:,0,0,5],ax =ax[1,2], cmap = cmap0, vmin = 0, vmax =1)
set_labels(ax[0,0])
set_labels(ax[0,1])
set_labels(ax[0,2])
set_labels(ax[1,0])
set_labels(ax[1,1])
set_labels(ax[1,2])
fig.tight_layout()

fig.suptitle("Learned Transitions given action cooperate")
fig.tight_layout()

# %%
def set_labels(axis):
    axis.set_xticklabels(['Prosocial','Antisocial'])
    axis.set_yticklabels(['PS','AS'])

fig, ax = plt.subplots(2,3, figsize = (12,4))

img1 = sns.heatmap(B2_over_time_all[-1,:,:,1,0,0],ax =ax[0,0], cmap = cmap0, vmin = 0, vmax =1)
img2 = sns.heatmap(B2_over_time_all[-1,:,:,1,0,1],ax =ax[0,1], cmap = cmap0, vmin = 0, vmax =1)
img3 = sns.heatmap(B2_over_time_all[-1,:,:,1,0,2],ax =ax[0,2], cmap = cmap0, vmin = 0, vmax =1)
img4 = sns.heatmap(B2_over_time_all[-1,:,:,1,0,3],ax =ax[1,0], cmap = cmap0, vmin = 0, vmax =1)
img5 = sns.heatmap(B2_over_time_all[-1,:,:,1,0,4],ax =ax[1,1], cmap = cmap0, vmin = 0, vmax =1)
img6 = sns.heatmap(B2_over_time_all[-1,:,:,1,0,5],ax =ax[1,2], cmap = cmap0, vmin = 0, vmax =1)
set_labels(ax[0,0])
set_labels(ax[0,1])
set_labels(ax[0,2])
set_labels(ax[1,0])
set_labels(ax[1,1])
set_labels(ax[1,2])
fig.tight_layout()

fig.suptitle("Learned Transitions given action defect")
fig.tight_layout()

# %%
for i in range(6):
    plt.plot(q_pi_over_time_all[:,0,0,i])
    plt.ylim([0,1])
    #plt.errorbar(range(200), q_pi_over_time_all[:,0,0,i,0], yerr=q_pi_over_time_all[:,0,0,i,1],alpha=0.5, ecolor = 'yellow')

    plt.show()

# %%
for i in range(6):
    fig, ax = plt.subplots()
    ax.grid(color='w', which = 'minor', linestyle='-', linewidth=2)
    ax.set_xlabel("Time")
    im = ax.imshow(actions_over_time_all[:,:,i].T,cmap ='gray', aspect = 10, vmin=0, vmax =1)
    ax.set_yticks([0, 1], labels=["Agent 1", "Agent 2"])
    plt.title(
        f"Actions over time for A precisions"
    )
    plt.show()
