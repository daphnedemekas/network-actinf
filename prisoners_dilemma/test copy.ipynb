# %%
import numpy as np

# %%
import seaborn as sns

# %%
actions_over_time_all = np.load('sweeps2/p_3_to_4.5_lr_0.5_pa_2/actions_over_time_all.npy')

# %%
B1_over_time_all = np.load('sweeps2/p_3_to_4.5_lr_0.5_pa_2/B1_over_time_all.npy')

# %%
B2_over_time_all = np.load('sweeps2/p_3_to_4.5_lr_0.5_pa_2/B2_over_time_all.npy')

# %%
q_pi_over_time_all = np.load('sweeps2/p_3_to_4.5_lr_0.5_pa_2/q_pi_over_time_all.npy')

# %%
q_pi_over_time_all.shape
# Out:
# (200, 2, 2, 6, 2)

# %%
B1_over_time_all.shape
# Out:
# (200, 4, 4, 2, 2, 6, 2)

# %%
import matplotlib.pyplot as plt

# %%
from matplotlib.colors import LinearSegmentedColormap

cmap0 = LinearSegmentedColormap.from_list("", ["white", "black"])

# %%
B1_over_time_all_1 = np.load('sweep/3,3.5,4,4.5,5,5.5,6/B1_over_time_all.npy')
B2_over_time_all_1 = np.load('sweep/3,3.5,4,4.5,5,5.5,6/B1_over_time_all.npy')

# %%
q_pi_over_time_all_1 = np.load('sweep/3,3.5,4,4.5,5,5.5,6/q_pi_over_time_all.npy')

# %%
def set_labels(axis):
    axis.set_xticklabels(['CC','CD','DC','DD'],fontsize =14)
    axis.set_yticklabels(['CC','CD'],fontsize =14)
    axis.set_xlabel(r'$s_t$',fontsize =20)

    axis.set_ylabel(r'$s_{t+1}$',fontsize =20)

fig, ax = plt.subplots(3,3, figsize = (20,10))

img1 = sns.heatmap(B1_over_time_all_1[-1,:2,:,0,0,0,0],ax =ax[0,0], cmap = cmap0, vmin = 0, vmax =1)
img2 = sns.heatmap(B1_over_time_all_1[-1,:2,:,0,0,1,0],ax =ax[0,1], cmap = cmap0, vmin = 0, vmax =1)
img3 = sns.heatmap(B1_over_time_all[-1,:2,:,0,0,2,0],ax =ax[0,2], cmap = cmap0, vmin = 0, vmax =1)
img4 = sns.heatmap(B1_over_time_all[-1,:2,:,0,0,3,0],ax =ax[1,0], cmap = cmap0, vmin = 0, vmax =1)
img5 = sns.heatmap(B1_over_time_all[-1,:2,:,0,0,4,0],ax =ax[1,1], cmap = cmap0, vmin = 0, vmax =1)
img6 = sns.heatmap(B1_over_time_all[-1,:2,:,0,0,5,0],ax =ax[1,2], cmap = cmap0, vmin = 0, vmax =1)
img7 = sns.heatmap(B1_over_time_all_1[-1,:2,:,0,0,2,0],ax =ax[2,0], cmap = cmap0, vmin = 0, vmax =1)
img8 = sns.heatmap(B1_over_time_all_1[-1,:2,:,0,0,3,0],ax =ax[2,1], cmap = cmap0, vmin = 0, vmax =1)
img9 = sns.heatmap(B1_over_time_all_1[-1,:2,:,0,0,4,0],ax =ax[2,2], cmap = cmap0, vmin = 0, vmax =1)


ax[0,0].set_title(r'$\gamma$' + '=3.0',fontsize =20)
ax[0,1].set_title(r'$\gamma$' + '=3.5',fontsize =20)

ax[0,2].set_title(r'$\gamma$' + '=3.7',fontsize =20)
ax[1,0].set_title(r'$\gamma$' + '=3.8',fontsize =20)
ax[1,1].set_title(r'$\gamma$' + '=3.9',fontsize =20)
ax[1,2].set_title(r'$\gamma$' + '=4.0',fontsize =20)
ax[2,0].set_title(r'$\gamma$' + '=4.5',fontsize =20)
ax[2,1].set_title(r'$\gamma$' + '=5.0',fontsize =20)
ax[2,2].set_title(r'$\gamma$' + '=5.5',fontsize =20)

set_labels(ax[0,0])
set_labels(ax[0,1])
set_labels(ax[0,2])
set_labels(ax[1,0])
set_labels(ax[1,1])
set_labels(ax[1,2])
set_labels(ax[2,0])
set_labels(ax[2,1])
set_labels(ax[2,2])
fig.tight_layout()
plt.savefig("Learned Transitions A matrix precision")

# %%
def set_labels(axis):
    axis.set_xticklabels(['CC','CD','DC','DD'],fontsize =14)
    axis.set_yticklabels(['CC','CD'],fontsize =14)
    axis.set_xlabel(r'$s_t$',fontsize =20)

    axis.set_ylabel(r'$s_{t+1}$',fontsize =20)

fig, ax = plt.subplots(3,3, figsize = (20,10))

img1 = sns.heatmap(B1_over_time_all_1[-1,2:,:,1,0,0,0],ax =ax[0,0], cmap = cmap0, vmin = 0, vmax =1)
img2 = sns.heatmap(B1_over_time_all_1[-1,2:,:,1,0,1,0],ax =ax[0,1], cmap = cmap0, vmin = 0, vmax =1)
img3 = sns.heatmap(B1_over_time_all[-1,2:,:,1,0,2,0],ax =ax[0,2], cmap = cmap0, vmin = 0, vmax =1)
img4 = sns.heatmap(B1_over_time_all[-1,2:,:,1,0,3,0],ax =ax[1,0], cmap = cmap0, vmin = 0, vmax =1)
img5 = sns.heatmap(B1_over_time_all[-1,2:,:,1,0,4,0],ax =ax[1,1], cmap = cmap0, vmin = 0, vmax =1)
img6 = sns.heatmap(B1_over_time_all[-1,2:,:,1,0,5,0],ax =ax[1,2], cmap = cmap0, vmin = 0, vmax =1)
img7 = sns.heatmap(B1_over_time_all_1[-1,2:,:,1,0,2,0],ax =ax[2,0], cmap = cmap0, vmin = 0, vmax =1)
img8 = sns.heatmap(B1_over_time_all_1[-1,2:,:,1,0,3,0],ax =ax[2,1], cmap = cmap0, vmin = 0, vmax =1)
img9 = sns.heatmap(B1_over_time_all_1[-1,2:,:,1,0,4,0],ax =ax[2,2], cmap = cmap0, vmin = 0, vmax =1)


ax[0,0].set_title(r'$\gamma$' + '=3.0',fontsize =20)
ax[0,1].set_title(r'$\gamma$' + '=3.5',fontsize =20)

ax[0,2].set_title(r'$\gamma$' + '=3.7',fontsize =20)
ax[1,0].set_title(r'$\gamma$' + '=3.8',fontsize =20)
ax[1,1].set_title(r'$\gamma$' + '=3.9',fontsize =20)
ax[1,2].set_title(r'$\gamma$' + '=4.0',fontsize =20)
ax[2,0].set_title(r'$\gamma$' + '=4.5',fontsize =20)
ax[2,1].set_title(r'$\gamma$' + '=5.0',fontsize =20)
ax[2,2].set_title(r'$\gamma$' + '=5.5',fontsize =20)

set_labels(ax[0,0])
set_labels(ax[0,1])
set_labels(ax[0,2])
set_labels(ax[1,0])
set_labels(ax[1,1])
set_labels(ax[1,2])
set_labels(ax[2,0])
set_labels(ax[2,1])
set_labels(ax[2,2])
fig.tight_layout()

fig.suptitle("Learned Transitions given action defect")
fig.tight_layout()

# %%
B2_over_time_all[-1,:,:,0,0,0,0]
# Out:
# array([[0.72739124, 0.70973029],
#        [0.27260876, 0.29026971]])

# %%
B2_over_time_all[-1,:,:,0,0,-1,0]
# Out:
# array([[0.63998394, 0.61922893],
#        [0.36001606, 0.38077107]])

# %%
def set_labels(axis):
    axis.set_xticklabels(['Prosocial','Antisocial'])
    axis.set_yticklabels(['PS','AS'])

fig, ax = plt.subplots(2,3, figsize = (12,4))

img1 = sns.heatmap(B2_over_time_all_1[-1,:,:,0,0,0,0],ax =ax[0,0], cmap = cmap0, vmin = 0, vmax =1)
img2 = sns.heatmap(B2_over_time_all_1[-1,:,:,0,0,1,0],ax =ax[0,1], cmap = cmap0, vmin = 0, vmax =1)
img3 = sns.heatmap(B2_over_time_all[-1,:,:,0,0,2,0],ax =ax[0,2], cmap = cmap0, vmin = 0, vmax =1)
img4 = sns.heatmap(B2_over_time_all[-1,:,:,0,0,3,0],ax =ax[1,0], cmap = cmap0, vmin = 0, vmax =1)
img5 = sns.heatmap(B2_over_time_all[-1,:,:,0,0,4,0],ax =ax[1,1], cmap = cmap0, vmin = 0, vmax =1)
img6 = sns.heatmap(B2_over_time_all[-1,:,:,0,0,5,0],ax =ax[1,2], cmap = cmap0, vmin = 0, vmax =1)
img2 = sns.heatmap(B2_over_time_all_1[-1,:,:,0,0,1,0],ax =ax[0,1], cmap = cmap0, vmin = 0, vmax =1)
img2 = sns.heatmap(B2_over_time_all_1[-1,:,:,0,0,1,0],ax =ax[0,1], cmap = cmap0, vmin = 0, vmax =1)
img2 = sns.heatmap(B2_over_time_all_1[-1,:,:,0,0,1,0],ax =ax[0,1], cmap = cmap0, vmin = 0, vmax =1)

set_labels(ax[0,0])
set_labels(ax[0,1])
set_labels(ax[0,2])
set_labels(ax[1,0])
set_labels(ax[1,1])
set_labels(ax[1,2])
fig.tight_layout()

fig.suptitle("Learned Transitions given action cooperate")
fig.tight_layout()

# %%
def set_labels(axis):
    axis.set_xticklabels(['Prosocial','Antisocial'])
    axis.set_yticklabels(['PS','AS'])

fig, ax = plt.subplots(3,3, figsize = (12,4))

img1 = sns.heatmap(B2_over_time_all[-1,:,:,1,0,0,0],ax =ax[0,0], cmap = cmap0, vmin = 0, vmax =1)
img2 = sns.heatmap(B2_over_time_all[-1,:,:,1,0,1,0],ax =ax[0,1], cmap = cmap0, vmin = 0, vmax =1)
img3 = sns.heatmap(B2_over_time_all[-1,:,:,1,0,2,0],ax =ax[0,2], cmap = cmap0, vmin = 0, vmax =1)
img4 = sns.heatmap(B2_over_time_all[-1,:,:,1,0,3,0],ax =ax[1,0], cmap = cmap0, vmin = 0, vmax =1)
img5 = sns.heatmap(B2_over_time_all[-1,:,:,1,0,4,0],ax =ax[1,1], cmap = cmap0, vmin = 0, vmax =1)
img6 = sns.heatmap(B2_over_time_all[-1,:,:,1,0,5,0],ax =ax[1,2], cmap = cmap0, vmin = 0, vmax =1)
img6 = sns.heatmap(B2_over_time_all[-1,:,:,1,0,2,0],ax =ax[2,0], cmap = cmap0, vmin = 0, vmax =1)
img6 = sns.heatmap(B2_over_time_all[-1,:,:,1,0,3,0],ax =ax[2,1], cmap = cmap0, vmin = 0, vmax =1)
img6 = sns.heatmap(B2_over_time_all[-1,:,:,1,0,4,0],ax =ax[2,2], cmap = cmap0, vmin = 0, vmax =1)

set_labels(ax[0,0])
set_labels(ax[0,1])
set_labels(ax[0,2])
set_labels(ax[1,0])
set_labels(ax[1,1])
set_labels(ax[1,2])
set_labels(ax[2,0])
set_labels(ax[2,1])
set_labels(ax[2,2])
fig.tight_layout()

fig.suptitle("Learned Transitions given action defect")
fig.tight_layout()

# %%
q_pi_over_time_all_1[0,0,0,:,0] = 0.5

# %%
fig = plt.figure(figsize = (8,6))


plt.plot(q_pi_over_time_all_1[:,0,0,0,0],alpha=0.6, label = r'$\gamma$' + '=3.0', color = 'lightblue')
plt.plot(q_pi_over_time_all_1[:,0,0,1,0],alpha=0.3, label = r'$\gamma$' + '=3.5', color = 'orange')
#plt.plot(q_pi_over_time_all[:,0,0,2,0],alpha=0.2)
#plt.plot(q_pi_over_time_all[:,0,0,3,0])
plt.plot(q_pi_over_time_all[:,0,0,4,0],alpha=0.3, label =r'$\gamma$' + '=3.9', color = 'blue')
plt.plot(q_pi_over_time_all[:,0,0,5,0],color = 'darkblue', label= r'$\gamma$' + '=4.0')
plt.plot(q_pi_over_time_all_1[:,0,0,3,0],color = 'purple', label = r'$\gamma$' + '=4.5')
#plt.plot(q_pi_over_time_all_1[:,0,0,3,0])
#plt.plot(q_pi_over_time_all_1[:,0,0,4,0],alpha=0.9)
plt.legend()
#plt.errorbar(range(200), q_pi_over_time_all[:,0,0,i,0], yerr=q_pi_over_time_all[:,0,0,i,1],alpha=0.5, ecolor = 'yellow')
plt.ylim(-0.1,1.1)
plt.xlabel("Time")
plt.ylabel(r'$p(u_t = C)$')
plt.savefig("Probability of cooperation over time")
plt.show()

# %%
for i in range(2,6):
    fig, ax = plt.subplots()
    ax.grid(color='w', which = 'minor', linestyle='-', linewidth=2)
    ax.set_xlabel("Time")
    im = ax.imshow(actions_over_time_all[:,:,i].T,cmap ='gray', aspect = 10)
    ax.set_yticks([0, 1], labels=["Agent 1", "Agent 2"])
    plt.title(
        f"Actions over time for A precisions"
    )
    plt.show()

# %%
actions_over_time_all = np.load('sweeps2/lr_0_to_1_pa3_p4/actions_over_time_all.npy')
B1_over_time_all = np.load('sweeps2/lr_0_to_1_pa3_p4/B1_over_time_all.npy')
B2_over_time_all = np.load('sweeps2/lr_0_to_1_pa3_p4/B2_over_time_all.npy')
q_pi_over_time_all = np.load('sweeps2/lr_0_to_1_pa3_p4/q_pi_over_time_all.npy')

# %%
actions_over_time_all_1 = np.load('sweep/lr_pB/actions_over_time_all.npy')
B1_over_time_all_1 = np.load('sweep/lr_pB/B1_over_time_all.npy')
B2_over_time_all_1 = np.load('sweep/lr_pB/B2_over_time_all.npy')
q_pi_over_time_all_1 = np.load('sweep/lr_pB/q_pi_over_time_all.npy')

# %%
def set_labels(axis):
    axis.set_xticklabels(['CC','CD','DC','DD'],fontsize =14)
    axis.set_yticklabels(['CC','CD'],fontsize =14)
    axis.set_xlabel(r'$s_t$',fontsize =20)

    axis.set_ylabel(r'$s_{t+1}$',fontsize =20)

fig, ax = plt.subplots(2,3, figsize = (20,7))

img1 = sns.heatmap(B1_over_time_all[-1,2:,:,1,0,0,0],ax =ax[0,0], cmap = cmap0, vmin = 0, vmax =1)
img2 = sns.heatmap(B1_over_time_all[-1,2:,:,1,0,1,0],ax =ax[0,1], cmap = cmap0, vmin = 0, vmax =1)
img3 = sns.heatmap(B1_over_time_all[-1,2:,:,1,0,2,0],ax =ax[0,2], cmap = cmap0, vmin = 0, vmax =1)
img4 = sns.heatmap(B1_over_time_all[-1,2:,:,1,0,3,0],ax =ax[1,0], cmap = cmap0, vmin = 0, vmax =1)
img5 = sns.heatmap(B1_over_time_all[-1,2:,:,1,0,4,0],ax =ax[1,1], cmap = cmap0, vmin = 0, vmax =1)
img6 = sns.heatmap(B1_over_time_all[-1,2:,:,1,0,5,0],ax =ax[1,2], cmap = cmap0, vmin = 0, vmax =1)

ax[0,0].set_title(r'$\eta$' + '=0.0',fontsize =20)
ax[0,1].set_title(r'$\eta$' + '=0.2',fontsize =20)

ax[0,2].set_title(r'$\eta$' + '=0.4',fontsize =20)
ax[1,0].set_title(r'$\eta$' + '=0.6',fontsize =20)
ax[1,1].set_title(r'$\eta$' + '=0.8',fontsize =20)
ax[1,2].set_title(r'$\eta$' + '=1.0',fontsize =20)

set_labels(ax[0,0])
set_labels(ax[0,1])
set_labels(ax[0,2])
set_labels(ax[1,0])
set_labels(ax[1,1])
set_labels(ax[1,2])
fig.tight_layout()
plt.savefig("Learning rate sweep")

fig.suptitle("Learned Transitions given action defect")
fig.tight_layout()

# %%
def set_labels(axis):
    axis.set_xticklabels(['CC','CD','DC','DD'])
    axis.set_yticklabels(['CC','CD'])

fig, ax = plt.subplots(2,3, figsize = (12,4))

img1 = sns.heatmap(B1_over_time_all[-1,2:,:,1,0,0,0],ax =ax[0,0], cmap = cmap0, vmin = 0, vmax =1)
img2 = sns.heatmap(B1_over_time_all[-1,2:,:,1,0,1,0],ax =ax[0,1], cmap = cmap0, vmin = 0, vmax =1)
img3 = sns.heatmap(B1_over_time_all[-1,2:,:,1,0,2,0],ax =ax[0,2], cmap = cmap0, vmin = 0, vmax =1)
img4 = sns.heatmap(B1_over_time_all[-1,2:,:,1,0,3,0],ax =ax[1,0], cmap = cmap0, vmin = 0, vmax =1)
img5 = sns.heatmap(B1_over_time_all[-1,2:,:,1,0,4,0],ax =ax[1,1], cmap = cmap0, vmin = 0, vmax =1)
img6 = sns.heatmap(B1_over_time_all[-1,2:,:,1,0,5,0],ax =ax[1,2], cmap = cmap0, vmin = 0, vmax =1)

ax[0,0].set_title(" lr = 0.0")
ax[0,1].set_title(" lr = 0.2")

ax[0,2].set_title(" lr = 0.4")
ax[1,0].set_title(" lr = 0.6")
ax[1,1].set_title(" lr = 0.8")
ax[1,2].set_title(" lr = 1.0")

set_labels(ax[0,0])
set_labels(ax[0,1])
set_labels(ax[0,2])
set_labels(ax[1,0])
set_labels(ax[1,1])
set_labels(ax[1,2])
fig.suptitle("Learned Transitions given action defect")
fig.tight_layout()

# %%
def set_labels(axis):
    axis.set_xticklabels(['Prosocial','Antisocial'])
    axis.set_yticklabels(['PS','AS'])

fig, ax = plt.subplots(2,3, figsize = (12,4))

img1 = sns.heatmap(B2_over_time_all[-1,:,:,0,0,0,0],ax =ax[0,0], cmap = cmap0, vmin = 0, vmax =1)
img2 = sns.heatmap(B2_over_time_all[-1,:,:,0,0,1,0],ax =ax[0,1], cmap = cmap0, vmin = 0, vmax =1)
img3 = sns.heatmap(B2_over_time_all[-1,:,:,0,0,2,0],ax =ax[0,2], cmap = cmap0, vmin = 0, vmax =1)
img4 = sns.heatmap(B2_over_time_all[-1,:,:,0,0,3,0],ax =ax[1,0], cmap = cmap0, vmin = 0, vmax =1)
img5 = sns.heatmap(B2_over_time_all[-1,:,:,0,0,4,0],ax =ax[1,1], cmap = cmap0, vmin = 0, vmax =1)
img6 = sns.heatmap(B2_over_time_all[-1,:,:,0,0,5,0],ax =ax[1,2], cmap = cmap0, vmin = 0, vmax =1)
set_labels(ax[0,0])
set_labels(ax[0,1])
set_labels(ax[0,2])
set_labels(ax[1,0])
set_labels(ax[1,1])
set_labels(ax[1,2])
fig.tight_layout()

fig.suptitle("Learned Transitions given action cooperate")
fig.tight_layout()

# %%
def set_labels(axis):
    axis.set_xticklabels(['Prosocial','Antisocial'])
    axis.set_yticklabels(['PS','AS'])

fig, ax = plt.subplots(2,3, figsize = (12,4))

img1 = sns.heatmap(B2_over_time_all[-1,:,:,1,0,0,0],ax =ax[0,0], cmap = cmap0, vmin = 0, vmax =1)
img2 = sns.heatmap(B2_over_time_all[-1,:,:,1,0,1,0],ax =ax[0,1], cmap = cmap0, vmin = 0, vmax =1)
img3 = sns.heatmap(B2_over_time_all[-1,:,:,1,0,2,0],ax =ax[0,2], cmap = cmap0, vmin = 0, vmax =1)
img4 = sns.heatmap(B2_over_time_all[-1,:,:,1,0,3,0],ax =ax[1,0], cmap = cmap0, vmin = 0, vmax =1)
img5 = sns.heatmap(B2_over_time_all[-1,:,:,1,0,4,0],ax =ax[1,1], cmap = cmap0, vmin = 0, vmax =1)
img6 = sns.heatmap(B2_over_time_all[-1,:,:,1,0,5,0],ax =ax[1,2], cmap = cmap0, vmin = 0, vmax =1)
set_labels(ax[0,0])
set_labels(ax[0,1])
set_labels(ax[0,2])
set_labels(ax[1,0])
set_labels(ax[1,1])
set_labels(ax[1,2])
fig.tight_layout()

fig.suptitle("Learned Transitions given action defect")
fig.tight_layout()

# %%
q_pi_over_time_all[0,0,0,:,0] = 0.5

# %%
for i in range(1,6):
    plt.plot(q_pi_over_time_all[:,0,0,i,0])
    #plt.errorbar(range(200), q_pi_over_time_all[:,0,0,i,0], yerr=q_pi_over_time_all[:,0,0,i,1],alpha=0.5, ecolor = 'yellow')

# %%
fig = plt.figure(figsize = (8,6))


plt.plot(q_pi_over_time_all[:,0,0,1,0],alpha=0.6, label = r'$\gamma$' + '=3.0', color = 'lightblue')
plt.plot(q_pi_over_time_all[:,0,0,2,0],alpha=0.3, label = r'$\gamma$' + '=3.5', color = 'orange')
#plt.plot(q_pi_over_time_all[:,0,0,2,0],alpha=0.2)
#plt.plot(q_pi_over_time_all[:,0,0,3,0])
plt.plot(q_pi_over_time_all[:,0,0,3,0],alpha=0.3, label =r'$\gamma$' + '=3.9', color = 'blue')
plt.plot(q_pi_over_time_all[:,0,0,4,0],color = 'darkblue', label= r'$\gamma$' + '=4.0')
plt.plot(q_pi_over_time_all[:,0,0,5,0],color = 'purple', label = r'$\gamma$' + '=4.5')
#plt.plot(q_pi_over_time_all_1[:,0,0,3,0])
#plt.plot(q_pi_over_time_all_1[:,0,0,4,0],alpha=0.9)
plt.legend()
#plt.errorbar(range(200), q_pi_over_time_all[:,0,0,i,0], yerr=q_pi_over_time_all[:,0,0,i,1],alpha=0.5, ecolor = 'yellow')
plt.ylim(0.98,1.0)
plt.xlabel("Time")
plt.ylabel(r'$p(u_t = C)$')
plt.savefig("Probability of cooperation over time")
plt.show()

# %%
for i in range(6):
    fig, ax = plt.subplots()
    ax.grid(color='w', which = 'minor', linestyle='-', linewidth=2)
    ax.set_xlabel("Time")
    im = ax.imshow(actions_over_time_all[:,:,i].T,cmap ='gray', aspect = 10)
    ax.set_yticks([0, 1], labels=["Agent 1", "Agent 2"])
    plt.title(
        f"Actions over time for A precisions"
    )
    plt.show()
